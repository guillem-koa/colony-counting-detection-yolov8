# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8m.pt')  # load a pretrained model (recommended for training)
model.train(data='datasets/msa-base.v2i.yolov8/data.yaml', epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.1.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.12 torch-2.0.1 CPU (Apple M2)
# ...
